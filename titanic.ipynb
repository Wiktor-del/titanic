# %%
import pandas as pd

# %%
train_data = pd.read_csv("/workspaces/titanic/train.csv")

# %%
train_data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
test_data = pd.read_csv("/workspaces/titanic/test.csv")

# %%
test_data.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
women = train_data.loc[train_data.Sex == 'female']
women.head(100)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 women = train_data.loc[train_data.Sex == 'female']
#       2 women.head(100)
#
# NameError: name 'train_data' is not defined

# %%
women = train_data.loc[train_data.Sex == 'female']["Survived"]
women.head(100)
# Out:
# 1      1
# 2      1
# 3      1
# 8      1
# 9      1
#       ..
# 269    1
# 272    1
# 274    1
# 275    1
# 276    0
# Name: Survived, Length: 100, dtype: int64

# %%
women_alive = sum(women)
all_women = len(women)

print(women_alive, all_women)
# Out:
# 233 314

# %%
rate_women = women_alive/all_women
print("% women who survived", rate_women *100)
# Out:
# % women who survived 74.20382165605095

# %% [markdown]
# ### TODO
#
# policzyć ratio men
# jeszcze raz trai.data

# %%
train_data.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 train_data.head()
#
# NameError: name 'train_data' is not defined

# %%
import pandas as pd

# %%
train_data = pd.read_csv("/workspaces/titanic/train.csv")

# %%
train_data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
test_data = pd.read_csv("/workspaces/titanic/test.csv")

# %%
test_data.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
male = train_data.loc[train_data.Sex == 'male']
male.head(100)
# Out:
#      PassengerId  Survived  Pclass                             Name   Sex  \
# 0              1         0       3          Braund, Mr. Owen Harris  male
# 4              5         0       3         Allen, Mr. William Henry  male
# 5              6         0       3                 Moran, Mr. James  male
# 6              7         0       1          McCarthy, Mr. Timothy J  male
# 7              8         0       3   Palsson, Master. Gosta Leonard  male
# ..           ...       ...     ...                              ...   ...
# 150          151         0       2       Bateman, Rev. Robert James  male
# 152          153         0       3                 Meo, Mr. Alfonzo  male
# 153          154         0       3  van Billiard, Mr. Austin Blyler  male
# 154          155         0       3            Olsen, Mr. Ole Martin  male
# 155          156         0       1      Williams, Mr. Charles Duane  male
#
#       Age  SibSp  Parch       Ticket     Fare Cabin Embarked
# ...

# %%
male = train_data.loc[train_data.Sex == 'male']["Survived"]
male.head(100)
# Out:
# 0      0
# 4      0
# 5      0
# 6      0
# 7      0
#       ..
# 150    0
# 152    0
# 153    0
# 154    0
# 155    0
# Name: Survived, Length: 100, dtype: int64

# %%
male_alive = sum(male)
all_male = len(male)

print(male_alive, all_male)
# Out:
# 109 577

# %%
rate_men = male_alive/all_male
print("% women who survived", rate_men *100)
# Out:
# % women who survived 18.890814558058924
